# %%
import sys
import pandas
import matplotlib
import seaborn

print(sys.version)
print(pandas.__version__)
print(matplotlib.__version__)
print(seaborn.__version__)
# Out:
# 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# 0.24.2
# 3.0.3
# 0.9.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# load dataset
games = pandas.read_csv("games.csv")
pandas.read_csv("games.csv")
# Out:
#            id                type  \
# 0       12333           boardgame
# 1      120677           boardgame
# 2      102794           boardgame
# 3       25613           boardgame
# 4        3076           boardgame
# 5       31260           boardgame
# 6      124742           boardgame
# 7       96848           boardgame
# 8       84876           boardgame
# 9       72125           boardgame
# 10       2651           boardgame
# 11     164153           boardgame
# 12     115746           boardgame
# 13     121921           boardgame
# 14      35677           boardgame
# 15      28720           boardgame
# 16     126163           boardgame
# 17     150376           boardgame
# 18      68448           boardgame
# 19      18602           boardgame
# 20     122515           boardgame
# 21      40834           boardgame
# 22      62219           boardgame
# 23      28143           boardgame
# 24     103885           boardgame
# 25         93           boardgame
# ...

# %%
print(games.columns)

print(games.shape)
# Out:
# Index(['id', 'type', 'name', 'yearpublished', 'minplayers', 'maxplayers',
#        'playingtime', 'minplaytime', 'maxplaytime', 'minage', 'users_rated',
#        'average_rating', 'bayes_average_rating', 'total_owners',
#        'total_traders', 'total_wanters', 'total_wishers', 'total_comments',
#        'total_weights', 'average_weight'],
#       dtype='object')
# (81312, 20)

# %%
plt.hist(games['average_rating'])
plt.show()

# %%
games = games[games['average_rating'] > 0]

# %%
games = games.dropna(axis=0)

# %%
plt.hist(games['average_rating'])
plt.show()

# %%
games.columns
# Out:
# Index(['id', 'type', 'name', 'yearpublished', 'minplayers', 'maxplayers',
#        'playingtime', 'minplaytime', 'maxplaytime', 'minage', 'users_rated',
#        'average_rating', 'bayes_average_rating', 'total_owners',
#        'total_traders', 'total_wanters', 'total_wishers', 'total_comments',
#        'total_weights', 'average_weight'],
#       dtype='object')

# %%
#get all data from dataset
columns = games.columns.tolist()

# %%
columns
# Out:
# ['id',
#  'type',
#  'name',
#  'yearpublished',
#  'minplayers',
#  'maxplayers',
#  'playingtime',
#  'minplaytime',
#  'maxplaytime',
#  'minage',
#  'users_rated',
#  'average_rating',
#  'bayes_average_rating',
#  'total_owners',
#  'total_traders',
#  'total_wanters',
#  'total_wishers',
#  'total_comments',
#  'total_weights',
#  'average_weight']

# %%
columns = [c for c in columns if c not in ["bayes_average_rating","average_rating","type","name","id"]]

# %%
columns
# Out:
# ['yearpublished',
#  'minplayers',
#  'maxplayers',
#  'playingtime',
#  'minplaytime',
#  'maxplaytime',
#  'minage',
#  'users_rated',
#  'total_owners',
#  'total_traders',
#  'total_wanters',
#  'total_wishers',
#  'total_comments',
#  'total_weights',
#  'average_weight']

# %%
#storing the variable we are predicting on

target ="average_rating"

# %%
# generate test and training dataset
from sklearn.model_selection import train_test_split

# generate training set 
train = games.sample(frac =0.8,random_state=1)

#select anything not in training set and put in test
test = games.loc[~games.index.isin(train.index)]

print(train.shape)
print(test.shape)
# Out:
# (45515, 20)
# (11379, 20)

# %%
# import linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Initialize model class
LR = LinearRegression()

# Fit model the training data
LR.fit(train[columns],train[target])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#generate predicts for test set
predictions = LR.predict(test[columns])

# compute error between our test predictions snd actual values
mean_squared_error(predictions, test[target])
# Out:
# 2.078819032629326

# %%
 from sklearn.ensemble import RandomForestRegressor
 
RFR= RandomForestRegressor(n_estimators=100,min_samples_leaf=10, random_state=1)
    
# fit the data
RFR.fit(train[columns],train[target])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=10, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
predictions=RFR.predict(test[columns])

mean_squared_error(predictions, test[target])
# Out:
# 1.4458560046071653
